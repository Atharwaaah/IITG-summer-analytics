# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train=pd.read_csv('training_set_features.csv')

# %%
X_train
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
y_train=pd.read_csv('training_set_labels.csv')

# %%
# y_train

# %%
X_train.set_index('respondent_id',inplace=True)
y_train.set_index('respondent_id',inplace=True)

# %%
# X_train

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6437 entries, 1 to 26703
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   xyz_concern                  6437 non-null   float64
#  1   xyz_knowledge                6437 non-null   float64
#  2   behavioral_antiviral_meds    6437 non-null   float64
#  3   behavioral_avoidance         6437 non-null   float64
#  4   behavioral_face_mask         6437 non-null   float64
#  5   behavioral_wash_hands        6437 non-null   float64
#  6   behavioral_large_gatherings  6437 non-null   float64
#  7   behavioral_outside_home      6437 non-null   float64
#  8   behavioral_touch_face        6437 non-null   float64
#  9   doctor_recc_xyz              6437 non-null   float64
#  10  doctor_recc_seasonal         6437 non-null   float64
#  11  chronic_med_condition        6437 non-null   float64
# ...

# %%
df=pd.concat([X_train,y_train],join='outer',axis=1)

# %%
df
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 1                      3.0            2.0                        0.0
# 7                      1.0            0.0                        0.0
# 10                     2.0            1.0                        0.0
# 11                     1.0            2.0                        0.0
# 15                     1.0            1.0                        0.0
# ...                    ...            ...                        ...
# 26681                  2.0            1.0                        0.0
# 26683                  1.0            2.0                        1.0
# 26690                  0.0            2.0                        0.0
# 26699                  2.0            2.0                        0.0
# 26703                  1.0            2.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6437 entries, 1 to 26703
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   xyz_concern                  6437 non-null   float64
#  1   xyz_knowledge                6437 non-null   float64
#  2   behavioral_antiviral_meds    6437 non-null   float64
#  3   behavioral_avoidance         6437 non-null   float64
#  4   behavioral_face_mask         6437 non-null   float64
#  5   behavioral_wash_hands        6437 non-null   float64
#  6   behavioral_large_gatherings  6437 non-null   float64
#  7   behavioral_outside_home      6437 non-null   float64
#  8   behavioral_touch_face        6437 non-null   float64
#  9   doctor_recc_xyz              6437 non-null   float64
#  10  doctor_recc_seasonal         6437 non-null   float64
#  11  chronic_med_condition        6437 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# xyz_concern                    0
# xyz_knowledge                  0
# behavioral_antiviral_meds      0
# behavioral_avoidance           0
# behavioral_face_mask           0
# behavioral_wash_hands          0
# behavioral_large_gatherings    0
# behavioral_outside_home        0
# behavioral_touch_face          0
# doctor_recc_xyz                0
# doctor_recc_seasonal           0
# chronic_med_condition          0
# child_under_6_months           0
# health_worker                  0
# health_insurance               0
# opinion_xyz_vacc_effective     0
# opinion_xyz_risk               0
# opinion_xyz_sick_from_vacc     0
# opinion_seas_vacc_effective    0
# opinion_seas_risk              0
# opinion_seas_sick_from_vacc    0
# household_adults               0
# household_children             0
# xyz_vaccine                    0
# seasonal_vaccine               0
# dtype: int64

# %%
X_train=df.drop(['age_group','education','race','sex','income_poverty','marital_status','rent_or_own','employment_status','hhs_geo_region','census_msa','employment_industry','employment_occupation','xyz_vaccine','seasonal_vaccine'],axis=1)

# %%
y_train1=df['xyz_vaccine']
y_train2=df['seasonal_vaccine']

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train1)
# Out:
# LogisticRegression()

# %%
X_test=pd.read_csv('test_set_features.csv')

# %%
X_test.columns
# Out:
# Index(['xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
#        'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'household_adults',
#        'household_children'],
#       dtype='object')

# %%
X_test
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                  2.0            2.0                        0.0
# 26708                  1.0            1.0                        0.0
# 26710                  1.0            1.0                        0.0
# 26711                  3.0            1.0                        1.0
# 26712                  2.0            2.0                        0.0
# ...                    ...            ...                        ...
# 53408                  1.0            1.0                        1.0
# 53409                  1.0            1.0                        0.0
# 53411                  3.0            1.0                        0.0
# 53412                  0.0            1.0                        0.0
# 53414                  2.0            1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
X_test.set_index('respondent_id',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31388\625681737.py in ?()
# ----> 1 X_test.set_index('respondent_id',inplace=True)
#
# C:\ProgramData\anaconda3\envs\requirements\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['respondent_id'] are in the columns"

# %%
X_test
# Out:
#                xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 26707                  2.0            2.0                        0.0
# 26708                  1.0            1.0                        0.0
# 26710                  1.0            1.0                        0.0
# 26711                  3.0            1.0                        1.0
# 26712                  2.0            2.0                        0.0
# ...                    ...            ...                        ...
# 53408                  1.0            1.0                        1.0
# 53409                  1.0            1.0                        0.0
# 53411                  3.0            1.0                        0.0
# 53412                  0.0            1.0                        0.0
# 53414                  2.0            1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# ...

# %%
# X_test.drop(['age_group','education','race','sex','income_poverty','marital_status','rent_or_own','employment_status','hhs_geo_region','census_msa','employment_industry','employment_occupation'],axis=1,inplace=True)
# y_test1=X_test['xyz_vaccine']
# y_test2=X_test['seasonal_vaccine']
# X_test.dropna(how='any',axis=0,inplace=True)

# %%
y_pred1=model.predict(X_test)

# %%
model2=LogisticRegression()

# %%
model2.fit(X_train,y_train2)
# Out:
# LogisticRegression()

# %%
y_pred2=model2.predict(X_test)

# %%
y_pred2
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
len(y_pred1)
# Out:
# 13513

# %%
len(y_pred2)
# Out:
# 13513

# %%
# df=pd.concat([X_train,y_train],join='outer',axis=1)
# ar=np.array(y_test1.reset_index()['respondent_id'])
xy_vaccine=pd.Series(y_pred1)
season_vaccine=pd.Series(y_pred2)
combined_ans=pd.concat([xy_vaccine,season_vaccine],join='outer',axis=1)

# %%
combined_ans=pd.concat([combined_ans,X_test.reset_index()['respondent_id']],join='outer',axis=1)

# %%
combined_ans.set_index('respondent_id',inplace=True)
combined_ans

# %%
combined_ans.rename(columns={0:'h1n1_vaccine',1:'seasonal_vaccine'},inplace=True)

# %%
combined_ans
# Out:
#                h1n1_vaccine  seasonal_vaccine
# respondent_id
# 26707                     0                 0
# 26708                     0                 0
# 26710                     0                 1
# 26711                     0                 1
# 26712                     1                 1
# ...                     ...               ...
# 53408                     0                 0
# 53409                     0                 0
# 53411                     0                 0
# 53412                     0                 0
# 53414                     1                 1
#
# [13513 rows x 2 columns]

# %%
combined_ans.to_csv('Submission_Atharva.csv')

# %%
from sklearn.linear_model import LinearRegression

# %%
model_31=LinearRegression()

# %%
model_31.fit(X_train,y_train1)
# Out:
# LinearRegression()

# %%
y_pred_31=model_31.predict(X_test)

# %%
model_32=LinearRegression()

# %%
model_32.fit(X_train,y_train2)
# Out:
# LinearRegression()

# %%
y_pred_32=model_32.predict(X_test)

# %%
xy_vaccine1=pd.Series(y_pred_31)
season_vaccine1=pd.Series(y_pred_32)
combined_ans_linear=pd.concat([xy_vaccine1,season_vaccine1],join='outer',axis=1)

# %%
combined_ans_linear
# Out:
#               0         1
# 0      0.159561  0.344501
# 1     -0.038721  0.023412
# 2      0.506179  0.735991
# 3      0.394803  0.603803
# 4      0.658895  0.980920
# ...         ...       ...
# 13508  0.040387  0.005052
# 13509  0.095672  0.137021
# 13510  0.049867  0.325909
# 13511  0.356571  0.449355
# 13512  0.541719  0.592899
#
# [13513 rows x 2 columns]

# %%
combined_ans_linear=pd.concat([combined_ans_linear,X_test.reset_index()['respondent_id']],join='outer',axis=1)

# %%
combined_ans_linear.set_index('respondent_id',inplace=True)

# %%
combined_ans_linear
# Out:
#                       0         1
# respondent_id
# 26707          0.159561  0.344501
# 26708         -0.038721  0.023412
# 26710          0.506179  0.735991
# 26711          0.394803  0.603803
# 26712          0.658895  0.980920
# ...                 ...       ...
# 53408          0.040387  0.005052
# 53409          0.095672  0.137021
# 53411          0.049867  0.325909
# 53412          0.356571  0.449355
# 53414          0.541719  0.592899
#
# [13513 rows x 2 columns]

# %%
combined_ans_linear.rename(columns={0:'h1n1_vaccine',1:'seasonal_vaccine'},inplace=True)

# %%
combined_ans_linear
# Out:
#                h1n1_vaccine  seasonal_vaccine
# respondent_id
# 26707              0.159561          0.344501
# 26708             -0.038721          0.023412
# 26710              0.506179          0.735991
# 26711              0.394803          0.603803
# 26712              0.658895          0.980920
# ...                     ...               ...
# 53408              0.040387          0.005052
# 53409              0.095672          0.137021
# 53411              0.049867          0.325909
# 53412              0.356571          0.449355
# 53414              0.541719          0.592899
#
# [13513 rows x 2 columns]

# %%
combined_ans_linear['h1n1_vaccine']=combined_ans_linear['h1n1_vaccine'].round(2)

# %%
combined_ans_linear['seasonal_vaccine']=combined_ans_linear['seasonal_vaccine'].round(2)

# %%
combined_ans_linear.to_csv('Submission_Atharva_Linear.csv')
